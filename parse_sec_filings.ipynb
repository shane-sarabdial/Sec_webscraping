# %%
import time

import requests
import urllib
from bs4 import BeautifulSoup
import pandas as pd

# %%
def make_url(base_url, comp):
    url = base_url

    #add each component to base url
    for c in comp:
        url ='{}/{}'.format(url, c)

    return url

base_url = r"https://www.sec.gov"
json_format = 'index.json'

# %%
#request url and decode
url = r"https://www.sec.gov/Archives/edgar/data/0000050863/000005086322000007/index.json"
headers = {'user-agent': 'sample text'}
content = requests.get(url,headers=headers).json()

for file in content['directory']['item']:

    if file['name'] == 'FilingSummary.xml':
        xml_summary =base_url + content['directory']['name'] + '/' +file['name']

        print('_' * 100)
        print('File Name: ' + file['name'])
        print('File Path: ' + xml_summary)
# Out:
# ____________________________________________________________________________________________________
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/FilingSummary.xml

# %%
# define a new base url that represents the filing folder. This will come in handy when we need to download the reports.
base_url = xml_summary.replace('FilingSummary.xml', '')

# request and parse the content
content = requests.get(xml_summary, headers=headers).content
soup = BeautifulSoup(content, 'lxml')
#print(soup)

# find the 'myreports' tag because this contains all the individual reports submitted.
reports = soup.find('myreports')

# I want a list to store all the individual components of the report, so create the master list.
master_reports = []

#loop through each report in the 'myreports' tag but avoid the last one as this will cause an error.
for report in reports.find_all('report')[:-1]:

    # let's create a dictionary to store all the different parts we need.
    report_dict = {}
    report_dict['name_short'] = report.shortname.text
    report_dict['name_long'] = report.longname.text
    report_dict['position'] = report.position.text
    report_dict['category'] = report.menucategory.text
    report_dict['url'] = base_url + report.htmlfilename.text

    # append the dictionary to the master list.
    master_reports.append(report_dict)

    # print the info to the user.
    print('-'*100)
    print(base_url + report.htmlfilename.text)
    print(report.longname.text)
    print(report.shortname.text)
    print(report.menucategory.text)
    print(report.position.text)
print(master_reports[1])
# Out:
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R1.htm
# 0001001 - Document - Cover Page
# Cover Page
# Cover
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R2.htm
# 0002002 - Document - Audit Information
# Audit Information
# Notes
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R3.htm
# 1001003 - Statement - Consolidated Statements of Income
# Consolidated Statements of Income
# Uncategorized
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R4.htm
# 1002004 - Statement - Consolidated Statements of Comprehensive Income
# Consolidated Statements of Comprehensive Income
# Statements
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R5.htm
# 1003005 - Statement - Consolidated Balance Sheets
# Consolidated Balance Sheets
# Statements
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R6.htm
# 1004006 - Statement - Consolidated Balance Sheets (Parenthetical)
# Consolidated Balance Sheets (Parenthetical)
# Statements
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R7.htm
# 1005007 - Statement - Consolidated Statements of Cash Flows
# Consolidated Statements of Cash Flows
# Statements
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R8.htm
# 1006008 - Statement - Consolidated Statements of Stockholders' Equity
# Consolidated Statements of Stockholders' Equity
# Statements
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R9.htm
# 1007009 - Statement - Consolidated Statements of Stockholders' Equity (Parenthetical)
# Consolidated Statements of Stockholders' Equity (Parenthetical)
# Statements
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R10.htm
# 2101101 - Disclosure - Basis of Presentation
# Basis of Presentation
# Notes
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R11.htm
# 2103102 - Disclosure - Accounting Policies
# Accounting Policies
# Notes
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R12.htm
# 2106103 - Disclosure - Operating Segments
# Operating Segments
# Notes
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R13.htm
# 2111104 - Disclosure - Earnings Per Share
# Earnings Per Share
# Notes
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R14.htm
# 2114105 - Disclosure - Contract Liabilities
# Contract Liabilities
# Notes
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R15.htm
# 2117106 - Disclosure - Other Financial Statement Details
# Other Financial Statement Details
# Notes
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R16.htm
# 2124107 - Disclosure - Restructuring and Other Charges
# Restructuring and Other Charges
# Notes
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R17.htm
# 2127108 - Disclosure - Income Taxes
# Income Taxes
# Notes
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R18.htm
# 2131109 - Disclosure - Investments
# Investments
# Notes
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R19.htm
# 2138110 - Disclosure - Acquisitions & Divestitures
# Acquisitions & Divestitures
# Notes
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R20.htm
# 2142111 - Disclosure - Goodwill
# Goodwill
# Notes
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R21.htm
# 2145112 - Disclosure - Identified Intangible Assets
# Identified Intangible Assets
# Notes
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R22.htm
# 2148113 - Disclosure - Borrowings
# Borrowings
# Notes
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R23.htm
# 2152114 - Disclosure - Fair Value
# Fair Value
# Notes
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R24.htm
# 2155115 - Disclosure - Other Comprehensive Income (Loss)
# Other Comprehensive Income (Loss)
# Notes
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R25.htm
# 2158116 - Disclosure - Derivative Financial Instruments
# Derivative Financial Instruments
# Notes
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R26.htm
# 2161117 - Disclosure - Retirement Benefit Plans
# Retirement Benefit Plans
# Notes
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R27.htm
# 2164118 - Disclosure - Employee Equity Incentive Plans
# Employee Equity Incentive Plans
# Notes
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R28.htm
# 2167119 - Disclosure - Commitments and Contingencies
# Commitments and Contingencies
# Notes
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R29.htm
# 2204201 - Disclosure - Accounting Policies (Policies)
# Accounting Policies (Policies)
# Policies
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R30.htm
# 2307301 - Disclosure - Operating Segments (Tables)
# Operating Segments (Tables)
# Tables
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R31.htm
# 2312302 - Disclosure - Earnings Per Share (Tables)
# Earnings Per Share (Tables)
# Tables
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R32.htm
# 2315303 - Disclosure - Contract Liabilities (Tables)
# Contract Liabilities (Tables)
# Tables
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R33.htm
# 2318304 - Disclosure - Other Financial Statement Details (Tables)
# Other Financial Statement Details (Tables)
# Tables
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R34.htm
# 2325305 - Disclosure - Restructuring and Other Charges (Tables)
# Restructuring and Other Charges (Tables)
# Tables
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R35.htm
# 2328306 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# Tables
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R36.htm
# 2332307 - Disclosure - Investments (Tables)
# Investments (Tables)
# Tables
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R37.htm
# 2339308 - Disclosure - Acquisitions & Divestitures (Tables)
# Acquisitions & Divestitures (Tables)
# Tables
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R38.htm
# 2343309 - Disclosure - Goodwill (Tables)
# Goodwill (Tables)
# Tables
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R39.htm
# 2346310 - Disclosure - Identified Intangible Assets (Tables)
# Identified Intangible Assets (Tables)
# Tables
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R40.htm
# 2349311 - Disclosure - Borrowings (Tables)
# Borrowings (Tables)
# Tables
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R41.htm
# 2353312 - Disclosure - Fair Value (Tables)
# Fair Value (Tables)
# Tables
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R64.htm
# 2436419 - Disclosure - Investments, Equity Method and Cost Method Investments (Detail)
# Investments, Equity Method and Cost Method Investments (Detail)
# Details
# 64
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R65.htm
# 2437420 - Disclosure - Investments, Non-Marketable Cost Method Investments (Detail)
# Investments, Non-Marketable Cost Method Investments (Detail)
# Details
# 65
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R66.htm
# 2440421 - Disclosure - Acquisitions (Details)
# Acquisitions (Details)
# Details
# 66
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R67.htm
# 2441422 - Disclosure - Divestitures (Details)
# Divestitures (Details)
# Details
# 67
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R68.htm
# 2444423 - Disclosure - Goodwill (Detail)
# Goodwill (Detail)
# Details
# 68
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R69.htm
# 2447424 - Disclosure - Identified Intangible Assets (Detail)
# Identified Intangible Assets (Detail)
# Details
# 69
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R70.htm
# 2450425 - Disclosure - Borrowings, Short-term Debt (Detail)
# Borrowings, Short-term Debt (Detail)
# Details
# 70
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R71.htm
# 2451426 - Disclosure - Borrowings, Long-term Debt (Detail)
# Borrowings, Long-term Debt (Detail)
# Details
# 71
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R72.htm
# 2454427 - Disclosure - Fair Value (Detail)
# Fair Value (Detail)
# Details
# 72
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R73.htm
# 2457428 - Disclosure - Other Comprehensive Income (Loss), Accumulated Other Comprehensive Income (Loss) (Detail)
# Other Comprehensive Income (Loss), Accumulated Other Comprehensive Income (Loss) (Detail)
# Details
# 73
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R74.htm
# 2460429 - Disclosure - Derivative Financial Instruments (Detail)
# Derivative Financial Instruments (Detail)
# Details
# 74
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R75.htm
# 2463430 - Disclosure - Retirement Benefit Plans (Detail)
# Retirement Benefit Plans (Detail)
# Details
# 75
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R76.htm
# 2466431 - Disclosure - Employee Equity Incentive Plans (Detail)
# Employee Equity Incentive Plans (Detail)
# Details
# 76
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R77.htm
# 2469432 - Disclosure - Leases (Details)
# Leases (Details)
# Details
# 77
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R78.htm
# 2470433 - Disclosure - Commitments (Details)
# Commitments (Details)
# Details
# 78
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R79.htm
# 2471434 - Disclosure - Contingencies (Details)
# Contingencies (Details)
# Details
# 79
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R80.htm
# 2472435 - Disclosure - Schedule of Payments on Operating Lease Liabilities (Details)
# Schedule of Payments on Operating Lease Liabilities (Details)
# Details
# 80
# {'name_short': 'Audit Information', 'name_long': '0002002 - Document - Audit Information', 'position': '2', 'category': 'Notes', 'url': 'https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R2.htm'}

# %%
# create the list to hold the statement urls
statements_url = []

for report_dict in master_reports:

    # define the statements we want to look for.
    item1 = r"Consolidated Balance Sheets"
    item2 = r"Consolidated Statements of Income"
    item3 = r"Consolidated Statements of Cash Flows"
    item4 = r"Consolidated Statements of Stockholder's (Deficit) Equity"

    # store them in a list.
    report_list = [item1, item2, item3, item4]

    # if the short name can be found in the report list.
    if report_dict['name_short'] in report_list:

        # print some info and store it in the statements url.
        print('-'*100)
        print(report_dict['name_short'])
        print(report_dict['url'])

        statements_url.append(report_dict['url'])
# Out:
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Income
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R3.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Balance Sheets
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R5.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Cash Flows
# https://www.sec.gov/Archives/edgar/data/50863/000005086322000007/R7.htm

# %%
# let's assume we want all the statements in a single data set.
statements_data = []

# loop through each statement url
for statement in statements_url:

    # define a dictionary that will store the different parts of the statement.
    statement_data = {}
    statement_data['headers'] = []
    statement_data['sections'] = []
    statement_data['data'] = []
    
    # request the statement file content
    content = requests.get(statement,headers=headers).content
    report_soup = BeautifulSoup(content, 'html')

    # find all the rows, figure out what type of row it is, parse the elements, and store in the statement file list.
    for index, row in enumerate(report_soup.table.find_all('tr')):
        
        # first let's get all the elements.
        cols = row.find_all('td')
        
        # if it's a regular row and not a section or a table header
        if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0): 
            reg_row = [ele.text.strip() for ele in cols]
            statement_data['data'].append(reg_row)
            
        # if it's a regular row and a section but not a table header
        elif (len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0):
            sec_row = cols[0].text.strip()
            statement_data['sections'].append(sec_row)
            
        # finally if it's not any of those it must be a header
        elif (len(row.find_all('th')) != 0):            
            hed_row = [ele.text.strip() for ele in row.find_all('th')]
            statement_data['headers'].append(hed_row)
            
        else:            
            print('We encountered an error.')

    # append it to the master list.
    statements_data.append(statement_data)

# %%
# Grab the proper components
balance_header =  statements_data[1]['headers']
balance_hed = [item[1:] for item in balance_header]
balance_data = statements_data[1]['data']

# Put the data in a DataFrame
balance_df = pd.DataFrame(balance_data)

# Display
print('-'*100)
print('Before Reindexing')
print('-'*100)
display(balance_df.head())

# Define the Index column, rename it, and we need to make sure to drop the old column once we reindex.
balance_df.index = balance_df[0]
balance_df.index.name = 'Category'
balance_df = balance_df.drop(0, axis = 1)

# Display
print('-'*100)
print('Before Regex')
print('-'*100)
display(balance_df.head())

# Get rid of the '$', '(', ')', and convert the '' to NaNs.
balance_df = balance_df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)

# Display
print('-'*100)
print('Before type conversion')
print('-'*100)
display(balance_df.head())
balance_df.head()

# everything is a string, so let's convert all the data to a float.
balance_df = balance_df.astype(float)

# Change the column headers
balance_df.columns = balance_hed

# Display
print('-'*100)
print('Final Product')
print('-'*100)

# show the df
balance_df

# drop the data in a CSV file if need be.
# income_df.to_csv('income_state.csv')
# Out:
# ----------------------------------------------------------------------------------------------------
# Before Reindexing
# ----------------------------------------------------------------------------------------------------
#                                                    0        1        2
# 0  Cash, Cash Equivalents, Restricted Cash and Re...  $ 4,827  $ 5,865
# 1                             Short-term investments    2,103    2,292
# 2                                     Trading assets   21,483   15,738
# 3  Accounts receivable, net of allowance for doub...    9,457    6,782
# 4                                        Inventories   10,776    8,427
# ----------------------------------------------------------------------------------------------------
# Before Regex
# ----------------------------------------------------------------------------------------------------
#                                                           1        2
# Category
# Cash, Cash Equivalents, Restricted Cash and Res...  $ 4,827  $ 5,865
# Short-term investments                                2,103    2,292
# Trading assets                                       21,483   15,738
# Accounts receivable, net of allowance for doubt...    9,457    6,782
# Inventories                                          10,776    8,427
# ----------------------------------------------------------------------------------------------------
# Before type conversion
# ----------------------------------------------------------------------------------------------------
#                                                         1      2
# Category
# Cash, Cash Equivalents, Restricted Cash and Res...   4827   5865
# Short-term investments                               2103   2292
# Trading assets                                      21483  15738
# Accounts receivable, net of allowance for doubt...   9457   6782
# Inventories                                         10776   8427
# ----------------------------------------------------------------------------------------------------
# Final Product
# ----------------------------------------------------------------------------------------------------
#                                                    Dec. 25, 2021 Dec. 26, 2020
# Category
# Cash, Cash Equivalents, Restricted Cash and Res...        4827.0        5865.0
# Short-term investments                                    2103.0        2292.0
# Trading assets                                           21483.0       15738.0
# Accounts receivable, net of allowance for doubt...        9457.0        6782.0
# Inventories                                              10776.0        8427.0
# Assets held for sale                                      6942.0        5400.0
# Other current assets                                      2130.0        2745.0
# Total current assets                                     57718.0       47249.0
# Property, plant and equipment, net                       63245.0       56584.0
# Equity investments                                        6298.0        5152.0
# Other long-term investments                                840.0        2192.0
# Goodwill                                                 26963.0       26971.0
# Identified intangible assets, net                         7270.0        9026.0
# Other long-term assets                                    6072.0        5917.0
# Total assets                                            168406.0      153091.0
# Short-term debt                                           4591.0        2504.0
# Accounts payable                                          5747.0        5581.0
# Accrued compensation and benefits                         4535.0        3999.0
# Other accrued liabilities                                12589.0       12670.0
# Total current liabilities                                27462.0       24754.0
# Debt                                                     33510.0       33897.0
# Contract Liabilities                                       185.0        1367.0
# Income taxes payable, non-current                         4305.0        4578.0
# Deferred income taxes                                     2667.0        3843.0
# Other long-term liabilities                               4886.0        3614.0
# Commitments and Contingencies (Note 19)                      NaN           NaN
# Preferred stock, $0.001 par value, 50 shares au...           0.0           0.0
# Common stock, $0.001 par value, 10,000 shares a...       28006.0       25556.0
# Accumulated other comprehensive income (loss)             -880.0        -751.0
# Retained earnings                                        68265.0       56233.0
# Total stockholders' equity                               95391.0       81038.0
# Total liabilities and stockholders' equity              168406.0      153091.0

# %%
# Grab the proper components
income_header =  statements_data[0]['headers'][1]
income_data = statements_data[0]['data']

# Put the data in a DataFrame
income_df = pd.DataFrame(income_data)

# Display
print('-'*100)
print('Before Reindexing')
print('-'*100)
display(income_df.head())

# Define the Index column, rename it, and we need to make sure to drop the old column once we reindex.
income_df.index = income_df[0]
income_df.index.name = 'Category'
income_df = income_df.drop(0, axis = 1)

# Display
print('-'*100)
print('Before Regex')
print('-'*100)
display(income_df.head())

# Get rid of the '$', '(', ')', and convert the '' to NaNs.
income_df = income_df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)

# Display
print('-'*100)
print('Before type conversion')
print('-'*100)
display(income_df.head())

# everything is a string, so let's convert all the data to a float.
income_df = income_df.astype(float)

# Change the column headers
income_df.columns = income_header

# Display
print('-'*100)
print('Final Product')
print('-'*100)

# show the df
income_df

# drop the data in a CSV file if need be.
# income_df.to_csv('income_state.csv')
# Out:
# ----------------------------------------------------------------------------------------------------
# Before Reindexing
# ----------------------------------------------------------------------------------------------------
#                                        0         1         2         3
# 0                            Net revenue  $ 79,024  $ 77,867  $ 71,965
# 1                          Cost of sales    35,209    34,255    29,825
# 2                           Gross margin    43,815    43,612    42,140
# 3               Research and development    15,190    13,556    13,362
# 4  Marketing, general and administrative     6,543     6,180     6,350
# ----------------------------------------------------------------------------------------------------
# Before Regex
# ----------------------------------------------------------------------------------------------------
#                                               1         2         3
# Category
# Net revenue                            $ 79,024  $ 77,867  $ 71,965
# Cost of sales                            35,209    34,255    29,825
# Gross margin                             43,815    43,612    42,140
# Research and development                 15,190    13,556    13,362
# Marketing, general and administrative     6,543     6,180     6,350
# ----------------------------------------------------------------------------------------------------
# Before type conversion
# ----------------------------------------------------------------------------------------------------
#                                             1       2       3
# Category
# Net revenue                             79024   77867   71965
# Cost of sales                           35209   34255   29825
# Gross margin                            43815   43612   42140
# Research and development                15190   13556   13362
# Marketing, general and administrative    6543    6180    6350
# ----------------------------------------------------------------------------------------------------
# Final Product
# ----------------------------------------------------------------------------------------------------
#                                            Dec. 25, 2021  Dec. 26, 2020  \
# Category
# Net revenue                                     79024.00       77867.00
# Cost of sales                                   35209.00       34255.00
# Gross margin                                    43815.00       43612.00
# Research and development                        15190.00       13556.00
# Marketing, general and administrative            6543.00        6180.00
# Restructuring and other charges                  2626.00         198.00
# Operating expenses                              24359.00       19934.00
# Operating income                                19456.00       23678.00
# Gains (losses) on equity investments, net        2729.00        1904.00
# Interest and other, net                          -482.00        -504.00
# Income before taxes                             21703.00       25078.00
# Provision for taxes                              1835.00        4179.00
# Net income                                      19868.00       20899.00
# Earnings per share—basic                            4.89           4.98
# Earnings per share—diluted                          4.86           4.94
# Basic (shares)                                   4059.00        4199.00
# Diluted (shares)                                 4090.00        4232.00
#
#                                            Dec. 28, 2019
# Category
# Net revenue                                     71965.00
# Cost of sales                                   29825.00
# Gross margin                                    42140.00
# Research and development                        13362.00
# Marketing, general and administrative            6350.00
# Restructuring and other charges                   393.00
# Operating expenses                              20105.00
# Operating income                                22035.00
# Gains (losses) on equity investments, net        1539.00
# Interest and other, net                           484.00
# Income before taxes                             24058.00
# Provision for taxes                              3010.00
# Net income                                      21048.00
# Earnings per share—basic                            4.77
# Earnings per share—diluted                          4.71
# Basic (shares)                                   4417.00
# Diluted (shares)                                 4473.00

# %%
# Grab the proper components
cf_header =  statements_data[2]['headers'][1]
cf_data = statements_data[2]['data']

# Put the data in a DataFrame
cf_df = pd.DataFrame(cf_data)

# Display
print('-'*100)
print('Before Reindexing')
print('-'*100)
display(income_df.head())

# Define the Index column, rename it, and we need to make sure to drop the old column once we reindex.
cf_df.index = cf_df[0]
cf_df.index.name = 'Category'
cf_df = cf_df.drop(0, axis = 1)

# Display
print('-'*100)
print('Before Regex')
print('-'*100)
display(cf_df.head())

# Get rid of the '$', '(', ')', and convert the '' to NaNs.
cf_df = cf_df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)

# Display
print('-'*100)
print('Before type conversion')
print('-'*100)
display(cf_df.head())

# everything is a string, so let's convert all the data to a float.
cf_df = cf_df.astype(float)

# Change the column headers
cf_df.columns = cf_header

# Display
print('-'*100)
print('Final Product')
print('-'*100)

# show the df
cf_df

# drop the data in a CSV file if need be.
# income_df.to_csv('income_state.csv')
# Out:
# ----------------------------------------------------------------------------------------------------
# Before Reindexing
# ----------------------------------------------------------------------------------------------------
#                                        Dec. 25, 2021  Dec. 26, 2020  \
# Category
# Net revenue                                  79024.0        77867.0
# Cost of sales                                35209.0        34255.0
# Gross margin                                 43815.0        43612.0
# Research and development                     15190.0        13556.0
# Marketing, general and administrative         6543.0         6180.0
#
#                                        Dec. 28, 2019
# Category
# Net revenue                                  71965.0
# Cost of sales                                29825.0
# Gross margin                                 42140.0
# Research and development                     13362.0
# Marketing, general and administrative         6350.0
# ----------------------------------------------------------------------------------------------------
# Before Regex
# ----------------------------------------------------------------------------------------------------
#                                                       1        2        3
# Category
# Cash and cash equivalents, beginning of period  $ 5,865  $ 4,194  $ 3,019
# Net income                                       19,868   20,899   21,048
# Depreciation                                      9,953   10,482    9,204
# Share-based compensation                          2,036    1,854    1,705
# Restructuring and other charges                   2,626      198      393
# ----------------------------------------------------------------------------------------------------
# Before type conversion
# ----------------------------------------------------------------------------------------------------
#                                                     1      2      3
# Category
# Cash and cash equivalents, beginning of period   5865   4194   3019
# Net income                                      19868  20899  21048
# Depreciation                                     9953  10482   9204
# Share-based compensation                         2036   1854   1705
# Restructuring and other charges                  2626    198    393
# ----------------------------------------------------------------------------------------------------
# Final Product
# ----------------------------------------------------------------------------------------------------
#                                                     Dec. 25, 2021  \
# Category
# Cash and cash equivalents, beginning of period             5865.0
# Net income                                                19868.0
# Depreciation                                               9953.0
# Share-based compensation                                   2036.0
# Restructuring and other charges                            2626.0
# Amortization of intangibles                                1839.0
# (Gains) losses on equity investments, net                 -1458.0
# Accounts receivable                                       -2674.0
# Inventories                                               -2339.0
# Accounts payable                                           1190.0
# Accrued compensation and benefits                           515.0
# Customer deposits and prepaid supply agreements           -1583.0
# Income taxes                                               -441.0
# Other assets and liabilities                                459.0
# Total adjustments                                         10123.0
# Net cash provided by operating activities                 29991.0
# Additions to property, plant and equipment               -18733.0
# Additions to held for sale NAND property, plant...         1596.0
# Acquisitions, net of cash acquired                         -209.0
# Purchases of available-for-sale debt investments          -5051.0
# Maturities and sales of available-for-sale debt...         6467.0
# Purchases of trading assets                              -35503.0
# Maturities and sales of trading assets                    28832.0
# Purchases of equity investments                            -613.0
# Proceeds from Equity Method Investment, Distrib...          581.0
# Other investing                                             658.0
# Net cash used for investing activities                   -25167.0
# Issuance of term debt, net of issuance costs               4974.0
# Repayments of Long-term Debt                              -2500.0
# Proceeds from sales of common stock through emp...         1020.0
# Repurchase of common stock                                -2415.0
# Payment of dividends to stockholders                      -5644.0
# Other financing                                           -1297.0
# Net cash provided by (used for) financing activ...        -5862.0
# Net increase (decrease) in cash and cash equiva...        -1038.0
# Cash and cash equivalents, end of period                   4827.0
# Acquisition of property, plant and equipment in...         1619.0
# Interest, net of capitalized interest                       545.0
# Income taxes, net of refunds                               2263.0
